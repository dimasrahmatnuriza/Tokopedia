# %% [markdown]
# Pada Bagian ke-1 ini saya akan melakukan labeling dan pemrosesan prediksi klasifikasi dengan machine learning serta analisa teks ulasan pada Tokopedia.

# %%
# !pip install openpyxl
# Out:
# Requirement already satisfied: openpyxl in c:\users\asus\anaconda3\lib\site-packages (3.0.10)
# Requirement already satisfied: et_xmlfile in c:\users\asus\anaconda3\lib\site-packages (from openpyxl) (1.1.0)

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_excel('tokped_text.xlsx')
data.head()
# Out:
#    Unnamed: 0                                        Nama_Produk       Akun  \
# 0           1  Masker KF94 4 Ply Isi 10 Pcs Masker Medis Kese...  Stephanus
# 1           2  Masker KF94 4 Ply Isi 10 Pcs Masker Medis Kese...       Yati
# 2           3  Masker KF94 4 Ply Isi 10 Pcs Masker Medis Kese...      Husin
# 3           4  Masker KF94 4 Ply Isi 10 Pcs Masker Medis Kese...      Febby
# 4           5  Masker KF94 4 Ply Isi 10 Pcs Masker Medis Kese...     Rahmat
#
#                                               Ulasan  rate  \
# 0  keduakali beli tapi sayang yang kedua lambat d...     3
# 1                             bagus pengiriman cepat     5
# 2                              barang sesuai pesanan     4
# 3                             agak panas pas dipakai     5
# 4  barang sesuai permintaan dan bagus namun komun...     3
#
#                                      Ulasan_tokenize  \
# 0  ['keduakali', 'beli', 'tapi', 'sayang', 'yang'...
# 1                   ['bagus', 'pengiriman', 'cepat']
# 2                    ['barang', 'sesuai', 'pesanan']
# 3                ['agak', 'panas', 'pas', 'dipakai']
# 4  ['barang', 'sesuai', 'permintaan', 'dan', 'bag...
#
#                                    Ulasan_normalized  \
# 0  ['kedua kali', 'beli', 'tapi', 'sayang', 'yang...
# 1                   ['bagus', 'pengiriman', 'cepat']
# 2                    ['barang', 'sesuai', 'pesanan']
# 3            ['sedikit', 'panas', 'saat', 'dipakai']
# 4  ['barang', 'sesuai', 'permintaan', 'dan', 'bag...
#
#                                  Ulasan_stop_removed  \
# 0  ['kedua kali', 'beli', 'sayang', 'lambat', 're...
# 1                   ['bagus', 'pengiriman', 'cepat']
# 2                    ['barang', 'sesuai', 'pesanan']
# 3                               ['panas', 'dipakai']
# 4  ['barang', 'sesuai', 'permintaan', 'bagus', 'k...
#
#                                       Ulasan_Stemmed  \
# 0  ['dua kali', 'beli', 'sayang', 'lambat', 'resp...
# 1                        ['bagus', 'kirim', 'cepat']
# 2                      ['barang', 'sesuai', 'pesan']
# 3                                 ['panas', 'pakai']
# 4  ['barang', 'sesuai', 'minta', 'bagus', 'komuni...
#
#                                         Ulasan_clean
# 0  dua kali beli sayang lambat respon order pagi ...
# 1                                  bagus kirim cepat
# 2                                barang sesuai pesan
# 3                                        panas pakai
# 4  barang sesuai minta bagus komunikasi jual beli...

# %% [markdown]
# Pembagian data menjadi data sentimen berlabel positif dan negatif dengan angka 1 untuk positif dan angka 0 untuk negatif. Pengklasifikasian ini dilakukan pada ulasan yang memiliki rating 4 dan 5 sebagai sentimen positif dan rating 3 sampai 1 sebagai sentimen negatif.

# %%
label = []
for index, row in data.iterrows():
    if row["rate"] == 5 or row["rate"] == 4:
        label.append(1)
    else:
        label.append(0)

data["label"] = label

data
# Out:
#      Unnamed: 0                                        Nama_Produk       Akun  \
# 0             1  Masker KF94 4 Ply Isi 10 Pcs Masker Medis Kese...  Stephanus
# 1             2  Masker KF94 4 Ply Isi 10 Pcs Masker Medis Kese...       Yati
# 2             3  Masker KF94 4 Ply Isi 10 Pcs Masker Medis Kese...      Husin
# 3             4  Masker KF94 4 Ply Isi 10 Pcs Masker Medis Kese...      Febby
# 4             5  Masker KF94 4 Ply Isi 10 Pcs Masker Medis Kese...     Rahmat
# ..          ...                                                ...        ...
# 295         296              Buy 1 Get 1 - Masker Primero - Sachet      a***a
# 296         297              Buy 1 Get 1 - Masker Primero - Sachet      Teguh
# 297         298              Buy 1 Get 1 - Masker Primero - Sachet      F***a
# 298         299              Buy 1 Get 1 - Masker Primero - Sachet      N***a
# 299         300              Buy 1 Get 1 - Masker Primero - Sachet      G***g
#
#                                                 Ulasan  rate  \
# 0    keduakali beli tapi sayang yang kedua lambat d...     3
# 1                               bagus pengiriman cepat     5
# 2                                barang sesuai pesanan     4
# 3                               agak panas pas dipakai     5
# 4    barang sesuai permintaan dan bagus namun komun...     3
# ..                                                 ...   ...
# 295  barang yg dikirim tdk sesuai deskripsi tidak t...     1
# 296  kotaknya penyok disana sini mngkn dr pihak exp...     5
# 297  barang sesuai dan kualitas baik cuma kardusnya...     5
# 298  dapet harga promo jadi murah pengiriman agak l...     5
# 299  agak lama emang diproses sampe dikirim dan nya...     5
#
#                                        Ulasan_tokenize  \
# 0    ['keduakali', 'beli', 'tapi', 'sayang', 'yang'...
# 1                     ['bagus', 'pengiriman', 'cepat']
# 2                      ['barang', 'sesuai', 'pesanan']
# 3                  ['agak', 'panas', 'pas', 'dipakai']
# 4    ['barang', 'sesuai', 'permintaan', 'dan', 'bag...
# ..                                                 ...
# 295  ['barang', 'yg', 'dikirim', 'tdk', 'sesuai', '...
# 296  ['kotaknya', 'penyok', 'disana', 'sini', 'mngk...
# 297  ['barang', 'sesuai', 'dan', 'kualitas', 'baik'...
# 298  ['dapet', 'harga', 'promo', 'jadi', 'murah', '...
# 299  ['agak', 'lama', 'emang', 'diproses', 'sampe',...
#
#                                      Ulasan_normalized  \
# 0    ['kedua kali', 'beli', 'tapi', 'sayang', 'yang...
# 1                     ['bagus', 'pengiriman', 'cepat']
# 2                      ['barang', 'sesuai', 'pesanan']
# 3              ['sedikit', 'panas', 'saat', 'dipakai']
# 4    ['barang', 'sesuai', 'permintaan', 'dan', 'bag...
# ..                                                 ...
# 295  ['barang', 'yang', 'dikirim', 'tidak', 'sesuai...
# 296  ['kotaknya', 'penyok', 'disana', 'sini', 'mngk...
# 297  ['barang', 'sesuai', 'dan', 'kualitas', 'baik'...
# 298  ['dapat', 'harga', 'promo', 'jadi', 'murah', '...
# 299  ['sedikit', 'lama', 'memang', 'diproses', 'sam...
#
#                                    Ulasan_stop_removed  \
# 0    ['kedua kali', 'beli', 'sayang', 'lambat', 're...
# 1                     ['bagus', 'pengiriman', 'cepat']
# 2                      ['barang', 'sesuai', 'pesanan']
# 3                                 ['panas', 'dipakai']
# 4    ['barang', 'sesuai', 'permintaan', 'bagus', 'k...
# ..                                                 ...
# 295  ['barang', 'dikirim', 'sesuai', 'deskripsi', '...
# 296  ['kotaknya', 'penyok', 'disana', 'mngkn', 'exp...
# 297  ['barang', 'sesuai', 'kualitas', 'kardusnya', ...
# 298  ['harga', 'promo', 'murah', 'pengiriman', 'pro...
# 299  ['diproses', 'dikirim', 'sabar', 'ya', 'temant...
#
#                                         Ulasan_Stemmed  \
# 0    ['dua kali', 'beli', 'sayang', 'lambat', 'resp...
# 1                          ['bagus', 'kirim', 'cepat']
# 2                        ['barang', 'sesuai', 'pesan']
# 3                                   ['panas', 'pakai']
# 4    ['barang', 'sesuai', 'minta', 'bagus', 'komuni...
# ..                                                 ...
# 295  ['barang', 'kirim', 'sesuai', 'deskripsi', 'te...
# 296   ['kotak', 'penyok', 'sana', 'mngkn', 'expediai']
# 297  ['barang', 'sesuai', 'kualitas', 'kardus', 'pe...
# 298      ['harga', 'promo', 'murah', 'kirim', 'promo']
# 299  ['proses', 'kirim', 'sabar', 'ya', 'temanteman...
#
#                                           Ulasan_clean  label
# 0    dua kali beli sayang lambat respon order pagi ...      0
# 1                                    bagus kirim cepat      1
# 2                                  barang sesuai pesan      1
# 3                                          panas pakai      1
# 4    barang sesuai minta bagus komunikasi jual beli...      0
# ..                                                 ...    ...
# 295  barang kirim sesuai deskripsi tera ijin kemenk...      0
# 296                   kotak penyok sana mngkn expediai      1
# 297  barang sesuai kualitas kardus penyok next time...      1
# 298                      harga promo murah kirim promo      1
# 299  proses kirim sabar ya temanteman beli paket cu...      1
#
# [300 rows x 11 columns]

# %%
data['label'].value_counts()
# Out:
# 1    270
# 0     30
# Name: label, dtype: int64

# %% [markdown]
# # Menghitung Kata dengan TF-IDF

# %%
from sklearn.feature_extraction.text import CountVectorizer, TfidfTransformer

# %%
Ulasan = data['Ulasan_clean']

# %%
Ulasan.isnull().sum()
# Out:
# 11

# %%
Ulasan = Ulasan.fillna('tidak ada komentar')

# %%
cv = CountVectorizer()
term_fit = cv.fit(Ulasan)

print(len(term_fit.vocabulary_))
# Out:
# 468

# %%
term_fit.vocabulary_# Mengurutkan berdasarkan urutan abjad kata
# Out:
# {'dua': 100,
#  'kali': 167,
#  'beli': 40,
#  'sayang': 374,
#  'lambat': 207,
#  'respon': 357,
#  'order': 293,
#  'pagi': 304,
#  'kirim': 191,
#  'sore': 400,
#  'itu': 148,
#  'besok': 44,
#  'barang': 34,
#  'bagus': 24,
#  'sesuai': 389,
#  'harga': 128,
#  'cepat': 67,
#  'pesan': 318,
#  'panas': 308,
#  'pakai': 305,
#  'minta': 254,
#  'komunikasi': 195,
#  'jual': 162,
#  'pro': 331,
#  'aktif': 4,
#  'masker': 243,
#  'pengirimn': 315,
#  'produk': 333,
#  'konsumen': 197,
#  'suka': 406,
#  'makasih': 223,
#  'proses': 336,
#  'jemput': 156,
#  'kurir': 203,
#  'banget': 31,
#  'anjas': 16,
#  'pokok': 327,
#  'mantabspesan': 231,
#  'warna': 460,
#  'hitam': 135,
#  'putih': 342,
#  'pink': 323,
#  'ramah': 348,
#  'terima': 426,
#  'aman': 8,
#  'tidak': 432,
#  'ada': 1,
#  'komentar': 193,
#  'kecewa': 175,
#  'berat': 41,
#  'hijab': 133,
#  'tali': 412,
#  'gampang': 121,
#  'putus': 343,
#  'pendek': 313,
#  'estimasi': 108,
#  'baik': 27,
#  'karet': 172,
#  'headloop': 131,
#  'nya': 278,
#  'istri': 145,
#  'untung': 452,
#  'anak': 12,
#  'hrga': 136,
#  'murah': 264,
#  'layan': 214,
#  'muas': 261,
#  'medis': 245,
#  'lumayan': 221,
#  'tuju': 446,
#  'murahansmoga': 265,
#  'manfaat': 227,
#  'packing': 301,
#  'kasih': 173,
#  'ya': 464,
#  'sip': 393,
#  'nice': 273,
#  'one': 290,
#  'rumah': 365,
#  'thanks': 429,
#  'gan': 122,
#  'rusa': 366,
#  'favorite': 115,
#  'senang': 386,
#  'official': 282,
#  'store': 404,
#  'jamin': 152,
#  'packingan': 302,
#  'rapi': 351,
#  'bubblewrap': 60,
#  'janji': 154,
#  'puas': 338,
#  'kualitas': 200,
#  'okpengiriman': 287,
#  'bangetdapet': 32,
#  'cashback': 66,
#  'asli': 19,
#  'evorecomended': 110,
#  'hijau': 134,
#  'datang': 81,
#  'emas': 105,
#  'moga': 259,
#  'tambah': 413,
#  'cute': 78,
#  'pilih': 322,
#  'no': 274,
#  'keluarga': 179,
#  'fisik': 116,
#  'safety': 368,
#  'souvenir': 401,
#  'langgan': 209,
#  'rapat': 350,
#  'nyaman': 279,
#  'packaging': 299,
#  'mantaaaaaapp': 229,
#  'good': 124,
#  'quality': 345,
#  'percaya': 317,
#  'bandung': 30,
#  'mantap': 233,
#  'bungkus': 64,
#  'plastik': 325,
#  'segel': 376,
#  'mahal': 222,
#  'toko': 439,
#  'rekomendasi': 354,
#  're': 353,
#  'sekian': 380,
#  'baguz': 25,
#  'rugi': 364,
#  'mantul': 237,
#  'sealed': 375,
#  'debu': 83,
#  'kotor': 199,
#  'sippp': 394,
#  'manstap': 228,
#  'kalem': 166,
#  'bini': 48,
#  'baju': 28,
#  'tooopp': 441,
#  'puuaaassss': 344,
#  'foto': 118,
#  'langsung': 210,
#  'relatif': 355,
#  'sakit': 370,
#  'telinga': 419,
#  'ok': 283,
#  'jiwa': 158,
#  'turun': 448,
#  'next': 271,
#  'abal': 0,
#  'affordable': 3,
#  'thank': 428,
#  'you': 466,
#  'paket': 307,
#  'gambar': 120,
#  'skripsi': 397,
#  'seller': 384,
#  'semenjak': 385,
#  'wabah': 458,
#  'landa': 208,
#  'terimakasih': 427,
#  'beda': 38,
#  'merk': 248,
#  'brgnya': 56,
#  'kes': 185,
#  'mudah': 262,
#  'an': 11,
#  'bada': 23,
#  'isya': 146,
#  'loh': 219,
#  'pis': 324,
#  'sukses': 408,
#  'lapak': 212,
#  'barokah': 36,
#  'box': 54,
#  'customer': 77,
#  'deskripsimakasih': 87,
#  'original': 294,
#  'tebal': 418,
#  'tipis': 436,
#  'sih': 391,
#  'ragu': 347,
#  'banding': 29,
#  'type': 449,
#  'jenis': 157,
#  'ply': 326,
#  'masuk': 244,
#  'dus': 101,
#  'komplit': 194,
#  'fast': 113,
#  'responramahbarang': 359,
#  'mantaprekomendasi': 234,
#  'deh': 84,
#  'belanja': 39,
#  'mantaf': 232,
#  'oke': 284,
#  'enak': 106,
#  'overall': 297,
#  'seharihari': 377,
#  'packagingnya': 300,
#  'kardus': 171,
#  'penyok': 316,
#  'sisi': 395,
#  'hari': 130,
#  'napas': 268,
#  'cuman': 76,
#  'nerawangnya': 269,
#  'kayak': 174,
#  'kondisi': 196,
#  'deskripsi': 86,
#  'bgtthank': 46,
#  'admin': 2,
#  'bunda': 63,
#  'kemas': 181,
#  'ukur': 450,
#  'besar': 42,
#  'muka': 263,
#  'kadang': 163,
#  'merosot': 250,
#  'boxnya': 55,
#  'for': 117,
#  'nonmedical': 275,
#  'use': 453,
#  'its': 147,
#  'jelek': 155,
#  'bolong': 50,
#  'jahit': 150,
#  'isi': 143,
#  'kalo': 170,
#  'bos': 52,
#  'size': 396,
#  'kecil': 176,
#  'wajah': 459,
#  'lumanyan': 220,
#  'responsif': 361,
#  'lengkap': 216,
#  'utuh': 454,
#  'range': 349,
#  'mesan': 251,
#  'kemarin': 180,
#  'tunda': 447,
#  'kilat': 190,
#  'mantaps': 235,
#  'selamat': 381,
#  'kurrir': 204,
#  'langusng': 211,
#  'dikirimbelanja': 88,
#  'jm': 159,
#  'gosend': 125,
#  'bareng': 35,
#  'pic': 320,
#  'tq': 445,
#  'tawar': 417,
#  'bubble': 59,
#  'wrap': 463,
#  'kaliny': 168,
#  'on': 289,
#  'ditanyain': 94,
#  'ditawarin': 95,
#  'cancel': 65,
#  'orisinal': 295,
#  'keramean': 183,
#  'suruh': 411,
#  'tingkat': 434,
#  'service': 388,
#  'puass': 339,
#  'onemed': 291,
#  'late': 213,
#  'delivery': 85,
#  'brng': 57,
#  'andal': 15,
#  'pesawat': 319,
#  'bonus': 51,
#  'packingnya': 303,
#  'topmarkotop': 444,
#  'alias': 7,
#  'minggu': 252,
#  'kf': 188,
#  'mmasker': 256,
#  'ketat': 187,
#  'jam': 151,
#  'thankyou': 430,
#  'niattt': 272,
#  'vacum': 455,
#  'mmakasih': 255,
#  'pouch': 328,
#  'mantab': 230,
#  'tani': 415,
#  'terbang': 425,
#  'sehat': 378,
#  'nampaknya': 267,
#  'import': 139,
#  'china': 70,
#  'auto': 21,
#  'star': 403,
#  'youu': 467,
#  'gann': 123,
#  'free': 119,
#  'very': 456,
#  'response': 360,
#  'job': 160,
#  'bosssku': 53,
#  'pict': 321,
#  'cucu': 75,
#  'khusus': 189,
#  'sobek': 399,
#  'note': 277,
#  'terang': 424,
#  'lipat': 218,
#  'sajakrn': 369,
#  'dkrm': 96,
#  'dterima': 99,
#  'everything': 109,
#  'is': 142,
#  'puassssss': 341,
#  'model': 258,
#  'masak': 240,
#  'quantitas': 346,
#  'jossss': 161,
#  'wes': 462,
#  'biar': 47,
#  'nytrima': 281,
#  'bintang': 49,
#  'olshop': 288,
#  'okeeee': 285,
#  'pcs': 311,
#  'siiiip': 392,
#  'alhamdulillah': 6,
#  'peaanan': 312,
#  'cerita': 68,
#  'dikotakin': 89,
#  'bunafit': 62,
#  'kwalitas': 205,
#  'premium': 329,
#  'dngn': 97,
#  'bahan': 26,
#  'sek': 379,
#  'makasihhhh': 224,
#  'besi': 43,
#  'tempel': 422,
#  'maksimal': 225,
#  'kedau': 177,
#  'top': 442,
#  'mantulll': 238,
#  'okeeehhh': 286,
#  'reply': 356,
#  'chatdan': 69,
#  'buka': 61,
#  'dusnyarecommemded': 102,
#  'akurat': 5,
#  'pengirimannyamantul': 314,
#  'product': 332,
#  'and': 14,
#  'puasssss': 340,
#  'tipe': 435,
#  'coba': 71,
#  'jangkau': 153,
#  'better': 45,
#  'menurit': 246,
#  'lembut': 215,
#  'kuat': 201,
#  'ikin': 138,
#  'cocok': 72,
#  'diskon': 93,
#  'rising': 363,
#  'pakcagin': 306,
#  'faste': 114,
#  'respond': 358,
#  'halus': 127,
#  'merek': 247,
#  'asa': 18,
#  'indmret': 140,
#  'yasoalnya': 465,
#  'kesana': 186,
#  'nexcare': 270,
#  'kirimminta': 192,
#  'complain': 73,
#  'amburadul': 10,
#  'nyasampai': 280,
#  'isolasi': 144,
#  'dalem': 80,
#  'mantapssss': 236,
#  'rapipesanan': 352,
#  'mari': 239,
#  'jaga': 149,
#  'virus': 457,
#  'covid': 74,
#  'tks': 438,
#  'sukaaaaa': 407,
#  'anakanak': 13,
#  'pandemi': 309,
#  'ukurannyaselalu': 451,
#  'sritexgood': 402,
#  'supeeeer': 409,
#  'subuh': 405,
#  'malam': 226,
#  'warp': 461,
#  'kotak': 198,
#  'puaas': 337,
#  'awet': 22,
#  'siang': 390,
#  'thx': 431,
#  'ekspetasi': 104,
#  'toped': 443,
#  'amanseller': 9,
#  'kaliterima': 169,
#  'mohon': 260,
#  'keren': 184,
#  'gratis': 126,
#  'ongkir': 292,
#  'sameday': 371,
#  'selisih': 383,
#  'ribu': 362,
#  'doang': 98,
#  'kuping': 202,
#  'lama': 206,
#  'dikupingmantap': 90,
#  'dipakenya': 92,
#  'kaget': 164,
#  'bayang': 37,
#  'kejar': 178,
#  'normal': 276,
#  'btw': 58,
#  'kakak': 165,
#  'merkembossed': 249,
#  'ati': 20,
#  'teman': 420,
#  'tipu': 437,
#  'sampai': 372,
#  'ekspektasi': 103,
#  'dipacking': 91,
#  'higienis': 132,
#  'iram': 141,
#  'slow': 398,
#  'parahini': 310,
#  'hargany': 129,
#  'overpersis': 298,
#  'tokopedia': 440,
#  'selektif': 382,
#  'mutu': 266,
#  'over': 296,
#  'price': 330,
#  'sertifikasi': 387,
#  'daily': 79,
#  'maskdijual': 242,
#  'surgical': 410,
#  'mask': 241,
#  'tera': 423,
#  'ijin': 137,
#  'kemenkes': 182,
#  'tanggal': 414,
#  'exp': 111,
#  'date': 82,
#  'lindung': 217,
#  'sana': 373,
#  'mngkn': 257,
#  'expediai': 112,
#  'time': 433,
#  'promo': 334,
#  'tarik': 416,
#  'banyak': 33,
#  'promonya': 335,
#  'sabar': 367,
#  'temanteman': 421,
#  'enggak': 107,
#  'apa': 17,
#  'minimarket': 253}

# %%
#kolom pertama ini berarti jumlah dokumen
#kolom kedua berarti letak katanya
#kolom ketiga hasil dari tf

term_frequency_all =term_fit.transform(Ulasan)
print(term_frequency_all)
# Out:
#   (0, 24)	1
#   (0, 34)	1
#   (0, 40)	1
#   (0, 44)	1
#   (0, 100)	1
#   (0, 128)	1
#   (0, 148)	1
#   (0, 167)	1
#   (0, 191)	2
#   (0, 207)	1
#   (0, 293)	1
#   (0, 304)	1
#   (0, 357)	3
#   (0, 374)	1
#   (0, 389)	1
#   (0, 400)	1
#   (1, 24)	1
#   (1, 67)	1
#   (1, 191)	1
#   (2, 34)	1
#   (2, 318)	1
#   (2, 389)	1
#   (3, 305)	1
#   (3, 308)	1
#   (4, 4)	1
#   :	:
#   (299, 8)	1
#   (299, 17)	1
#   (299, 24)	1
#   (299, 40)	2
#   (299, 59)	1
#   (299, 71)	1
#   (299, 76)	1
#   (299, 107)	1
#   (299, 143)	1
#   (299, 191)	1
#   (299, 200)	2
#   (299, 243)	1
#   (299, 248)	1
#   (299, 253)	1
#   (299, 300)	1
#   (299, 305)	1
#   (299, 307)	1
#   (299, 311)	1
#   (299, 316)	1
#   (299, 336)	1
#   (299, 367)	1
#   (299, 375)	1
#   (299, 421)	1
#   (299, 463)	1
#   (299, 464)	1

# %%
ulasan_tf =Ulasan[1]
print(ulasan_tf)
# Out:
# bagus kirim cepat

# %%
term_frequency = term_fit.transform([ulasan_tf])
print(term_frequency)
# Out:
#   (0, 24)	1
#   (0, 67)	1
#   (0, 191)	1

# %%
dokumen = term_fit.transform(Ulasan) # perhitungan tf idf dalam 1 doc
tfidf_transformer = TfidfTransformer().fit(dokumen)
print(tfidf_transformer.idf_)

tfidf=tfidf_transformer.transform(term_frequency)
print(tfidf) # hasil manual dengan sistem phyton
# Out:
# [6.01396308 4.22220361 5.60849798 6.01396308 5.60849798 6.01396308
#  6.01396308 6.01396308 4.06805294 6.01396308 6.01396308 6.01396308
#  5.3208159  6.01396308 6.01396308 6.01396308 5.60849798 6.01396308
#  6.01396308 5.09767235 6.01396308 6.01396308 6.01396308 6.01396308
#  2.50241765 6.01396308 4.9153508  5.3208159  6.01396308 5.3208159
#  6.01396308 3.61606781 6.01396308 6.01396308 2.36330484 5.60849798
#  6.01396308 6.01396308 5.3208159  5.09767235 3.27312306 6.01396308
#  6.01396308 6.01396308 5.3208159  6.01396308 6.01396308 6.01396308
#  6.01396308 6.01396308 6.01396308 4.62766872 6.01396308 6.01396308
#  4.76120012 6.01396308 6.01396308 5.60849798 6.01396308 4.76120012
#  6.01396308 5.3208159  6.01396308 6.01396308 5.09767235 6.01396308
#  6.01396308 2.40304517 6.01396308 6.01396308 6.01396308 5.60849798
#  5.60849798 6.01396308 5.60849798 6.01396308 5.3208159  6.01396308
#  6.01396308 6.01396308 5.60849798 6.01396308 6.01396308 5.60849798
#  5.09767235 5.60849798 4.22220361 6.01396308 6.01396308 6.01396308
#  6.01396308 6.01396308 6.01396308 5.60849798 6.01396308 6.01396308
#  6.01396308 6.01396308 6.01396308 6.01396308 5.60849798 4.62766872
#  6.01396308 6.01396308 6.01396308 5.3208159  5.09767235 6.01396308
#  5.60849798 6.01396308 6.01396308 6.01396308 6.01396308 4.40452517
#  6.01396308 6.01396308 6.01396308 6.01396308 5.09767235 6.01396308
#  5.09767235 5.3208159  4.76120012 6.01396308 4.76120012 6.01396308
#  6.01396308 6.01396308 3.93452154 6.01396308 5.3208159  6.01396308
#  6.01396308 5.3208159  6.01396308 5.60849798 5.60849798 6.01396308
#  6.01396308 6.01396308 6.01396308 6.01396308 6.01396308 5.3208159
#  6.01396308 6.01396308 6.01396308 6.01396308 5.60849798 5.60849798
#  6.01396308 5.60849798 5.60849798 6.01396308 6.01396308 6.01396308
#  5.60849798 5.60849798 6.01396308 6.01396308 6.01396308 6.01396308
#  4.40452517 6.01396308 6.01396308 6.01396308 6.01396308 4.40452517
#  6.01396308 6.01396308 4.9153508  5.3208159  5.3208159  3.52905643
#  5.60849798 6.01396308 6.01396308 6.01396308 6.01396308 6.01396308
#  6.01396308 4.76120012 6.01396308 6.01396308 5.60849798 5.60849798
#  6.01396308 6.01396308 5.3208159  6.01396308 6.01396308 2.71812622
#  6.01396308 4.22220361 5.60849798 5.60849798 5.60849798 5.3208159
#  5.09767235 6.01396308 3.57161605 6.01396308 6.01396308 4.9153508
#  6.01396308 6.01396308 6.01396308 5.60849798 6.01396308 4.9153508
#  5.09767235 6.01396308 6.01396308 6.01396308 4.76120012 5.3208159
#  6.01396308 6.01396308 6.01396308 6.01396308 6.01396308 4.50988569
#  6.01396308 5.60849798 6.01396308 6.01396308 5.60849798 5.3208159
#  6.01396308 6.01396308 5.3208159  6.01396308 6.01396308 3.76267129
#  6.01396308 6.01396308 6.01396308 5.3208159  6.01396308 5.60849798
#  6.01396308 6.01396308 6.01396308 2.92292063 5.3208159  5.3208159
#  6.01396308 6.01396308 5.09767235 6.01396308 6.01396308 6.01396308
#  6.01396308 6.01396308 5.60849798 6.01396308 6.01396308 6.01396308
#  6.01396308 4.50988569 6.01396308 5.60849798 5.60849798 6.01396308
#  4.62766872 6.01396308 6.01396308 6.01396308 5.60849798 6.01396308
#  6.01396308 5.60849798 6.01396308 6.01396308 6.01396308 6.01396308
#  6.01396308 6.01396308 3.71137799 4.9153508  6.01396308 6.01396308
#  5.60849798 3.99906006 4.62766872 6.01396308 6.01396308 6.01396308
#  6.01396308 6.01396308 6.01396308 5.60849798 6.01396308 4.06805294
#  5.09767235 6.01396308 6.01396308 6.01396308 6.01396308 5.3208159
#  5.60849798 3.57161605 5.60849798 5.3208159  5.09767235 3.66258783
#  6.01396308 5.09767235 5.60849798 6.01396308 6.01396308 5.09767235
#  6.01396308 5.60849798 6.01396308 5.3208159  4.40452517 5.3208159
#  3.30591288 6.01396308 6.01396308 6.01396308 6.01396308 5.60849798
#  6.01396308 4.50988569 5.09767235 5.09767235 5.60849798 6.01396308
#  6.01396308 5.60849798 6.01396308 3.93452154 5.60849798 6.01396308
#  4.14216091 6.01396308 4.62766872 6.01396308 6.01396308 6.01396308
#  5.3208159  5.09767235 6.01396308 5.60849798 6.01396308 6.01396308
#  4.62766872 6.01396308 6.01396308 3.57161605 6.01396308 6.01396308
#  4.14216091 6.01396308 6.01396308 3.66258783 6.01396308 6.01396308
#  5.60849798 5.3208159  5.3208159  6.01396308 6.01396308 6.01396308
#  6.01396308 6.01396308 6.01396308 6.01396308 5.09767235 6.01396308
#  6.01396308 6.01396308 4.62766872 5.60849798 5.09767235 6.01396308
#  6.01396308 5.60849798 6.01396308 5.60849798 6.01396308 6.01396308
#  4.06805294 6.01396308 6.01396308 6.01396308 5.60849798 2.45861502
#  6.01396308 5.09767235 6.01396308 5.3208159  6.01396308 6.01396308
#  5.60849798 6.01396308 6.01396308 6.01396308 5.09767235 6.01396308
#  6.01396308 6.01396308 5.60849798 6.01396308 4.9153508  6.01396308
#  5.3208159  6.01396308 6.01396308 6.01396308 4.76120012 5.3208159
#  6.01396308 6.01396308 6.01396308 5.60849798 5.60849798 5.3208159
#  6.01396308 6.01396308 6.01396308 6.01396308 6.01396308 6.01396308
#  3.4112734  5.3208159  5.3208159  4.50988569 5.60849798 6.01396308
#  4.22220361 6.01396308 5.60849798 6.01396308 4.50988569 6.01396308
#  6.01396308 4.50988569 6.01396308 6.01396308 5.3208159  6.01396308
#  6.01396308 5.3208159  6.01396308 6.01396308 5.60849798 6.01396308
#  6.01396308 6.01396308 5.3208159  6.01396308 5.60849798 6.01396308
#  6.01396308 6.01396308 6.01396308 6.01396308 4.62766872 6.01396308
#  6.01396308 4.9153508  4.14216091 6.01396308 5.60849798 6.01396308]
#   (0, 191)	0.6167226304191588
#   (0, 67)	0.5452330834735575
#   (0, 24)	0.5677799589760018

# %% [markdown]
# # NLP

# %%
data_label=data[['Nama_Produk', 'Akun', 'Ulasan_clean','label']]

# %%
data_label['Ulasan_clean'] = data_label['Ulasan_clean'].fillna('tidak ada komentar')
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_1220\2681031520.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_label['Ulasan_clean'] = data_label['Ulasan_clean'].fillna('tidak ada komentar')

# %%
data_label.to_excel('data_label.xlsx')

# %%
sentimen_data=pd.value_counts(data_label["label"], sort= True)
sentimen_data.plot(kind= 'bar', color= ["green", "red"])
plt.title('Bar chart')
plt.show()

# %% [markdown]
# Dapat dilihat bahwa isi ulasan produk lebih banyak pada label sentimen 1 atau ulasan dengan rating postitif ini berarti pelanggan yang menggunakan marketplace Tokopedia dan melakukan transaksi pembelian pada produk masker Kesehatan merasa puas bertansaksi di marketplace Tokopedia dan prosuk masker Kesehatan sehingga memberikan feedback atau ulasan komentar lebih banyak yang positif.

# %%
# !pip install wordcloud
# Out:
# Collecting wordcloud
#   Downloading wordcloud-1.8.2.2-cp39-cp39-win_amd64.whl (153 kB)
#      -------------------------------------- 153.1/153.1 kB 3.0 MB/s eta 0:00:00
# Requirement already satisfied: matplotlib in c:\users\asus\anaconda3\lib\site-packages (from wordcloud) (3.5.2)
# Requirement already satisfied: pillow in c:\users\asus\anaconda3\lib\site-packages (from wordcloud) (9.2.0)
# Requirement already satisfied: numpy>=1.6.1 in c:\users\asus\anaconda3\lib\site-packages (from wordcloud) (1.21.5)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\asus\anaconda3\lib\site-packages (from matplotlib->wordcloud) (3.0.9)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\asus\anaconda3\lib\site-packages (from matplotlib->wordcloud) (1.4.2)
# Requirement already satisfied: packaging>=20.0 in c:\users\asus\anaconda3\lib\site-packages (from matplotlib->wordcloud) (21.3)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\asus\anaconda3\lib\site-packages (from matplotlib->wordcloud) (4.25.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\asus\anaconda3\lib\site-packages (from matplotlib->wordcloud) (0.11.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\asus\anaconda3\lib\site-packages (from matplotlib->wordcloud) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\asus\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib->wordcloud) (1.16.0)
# Installing collected packages: wordcloud
# Successfully installed wordcloud-1.8.2.2

# %%
from wordcloud import WordCloud

# %% [markdown]
# # Ulasan Negatif

# %%
train_s0 = data_label[data_label['label'] == 0]

# %%
train_s0['Ulasan_clean'] = train_s0['Ulasan_clean'].fillna('tidak ada komentar')
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_1220\4133483918.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_s0['Ulasan_clean'] = train_s0['Ulasan_clean'].fillna('tidak ada komentar')

# %%
train_s0
# Out:
#                                            Nama_Produk        Akun  \
# 0    Masker KF94 4 Ply Isi 10 Pcs Masker Medis Kese...   Stephanus
# 4    Masker KF94 4 Ply Isi 10 Pcs Masker Medis Kese...      Rahmat
# 8    Masker KF94 4 Ply Isi 10 Pcs Masker Medis Kese...       n***l
# 13   MASKER 3PLY IZIN KEMENKES MASKER MEDIS KESEHAT...      Renold
# 15   MASKER 3PLY IZIN KEMENKES MASKER MEDIS KESEHAT...      Ridwan
# 35                 Masker Evo PlusMed 4d Medis - Putih       J***a
# 56   Disposable Mask KN95 N95 Facemask Kesehatan Ma...      Anggia
# 84   ONEMED - Masker Karet 3 Ply / Masker Non-Medis...        Adhi
# 103  C care Duckbill 3D Stereo 3 Ply Isi 50 Pcs Mas...       Risca
# 115  Masker KN95 Alkindo Masker Medis 5ply 1 Box 10...      Duarte
# 116  Masker KN95 Alkindo Masker Medis 5ply 1 Box 10...       M***a
# 165  Facemask 50s / BOX Masker Wajah Kesehatan 3ply...  NURHASANAH
# 169  Facemask 50s / BOX Masker Wajah Kesehatan 3ply...        Jhon
# 170  Masker Karet Putih 3 Ply Daily Use Onemed Box ...        Luke
# 172  Masker Karet Putih 3 Ply Daily Use Onemed Box ...       H***h
# 192  Disposable Mask KN95 Facemask Kesehatan Masker...       M***r
# 198  Disposable Mask KN95 Facemask Kesehatan Masker...   Sekardewi
# 201  Masker KF94 4 Ply Isi 10 Pcs Masker Medis Kese...   Stephanus
# 202  Masker KF94 4 Ply Isi 10 Pcs Masker Medis Kese...      Rahmat
# 206  Masker KF94 4 Ply Isi 10 Pcs Masker Medis Kese...       n***l
# 242  Nexcare 3M Masker 3 Lapis Earloop 3 Ply Daily ...       n***a
# 244  Nexcare 3M Masker 3 Lapis Earloop 3 Ply Daily ...       Elike
# 266  Face Mask Earloop 50pcs Masker mulut/ Masker W...    Ariyanto
# 270  Goto Disposable Mask KN 95 Facemask 5Ply Earlo...       T***o
# 280  Madame Gie Protect You KN95 Mask - Masker Kese...       A***i
# 283  Madame Gie Protect You KN95 Mask - Masker Kese...     Afrizal
# 287  Madame Gie Protect You KN95 Mask - Masker Kese...        Joko
# 292              Buy 1 Get 1 - Masker Primero - Sachet       a***a
# 294              Buy 1 Get 1 - Masker Primero - Sachet       M***l
# 295              Buy 1 Get 1 - Masker Primero - Sachet       a***a
#
#                                           Ulasan_clean  label
# 0    dua kali beli sayang lambat respon order pagi ...      0
# 4    barang sesuai minta bagus komunikasi jual beli...      0
# 8        proses barang jemput kurir banget anjas pokok      0
# 13   kecewa berat masker hijab warna hitam tali mas...      0
# 15   karet headloop nya pendek istri pakai untung anak      0
# 35          pesan masker warna hijau datang warna pink      0
# 56                   bungkus plastik sealed debu kotor      0
# 84           tipis sih ragu banding type jenis ply ply      0
# 103                              masker tipis ya bunda      0
# 115  kualitas masker jelek masker bolong jahit isi ...      0
# 116                                       size telinga      0
# 165  fast respon kirim cepat sayang box khusus hija...      0
# 169                    pesan box hijab box model hijab      0
# 170                       masak debu masuk masker hari      0
# 172  tipis banget masker beda onemed warna putih tipis      0
# 192  cerita beli pcs dikotakin kes bunafit ply saya...      0
# 198         pesan plastik masker plastik masker masker      0
# 201  dua kali beli sayang lambat respon order pagi ...      0
# 202  barang sesuai minta bagus komunikasi jual beli...      0
# 206      proses barang jemput kurir banget anjas pokok      0
# 242  beli box bonus kf kirimminta produk foto prose...      0
# 244  packing amburadul dus masker penyok penyok nya...      0
# 266  merk dus masker merk kualitas ya masker merk p...      0
# 270                   tali nya sakit kuping pakai lama      0
# 280  kaget kemas sesuai bayang beli hrga kejar disk...      0
# 283  kayak masker jenis merkembossed ati teman tipu...      0
# 287                                 tidak ada komentar      0
# 292  deskripsi produk sesuai terima iram slow respo...      0
# 294  parahini masker hargany overpersis harga ribu ...      0
# 295  barang kirim sesuai deskripsi tera ijin kemenk...      0

# %%
all_text_s0 = ' '.join(word for word in train_s0["Ulasan_clean"])
wordcloud = WordCloud(colormap='Reds', width=1000, height=1000, mode='RGBA', background_color='white').generate(all_text_s0)
plt.figure(figsize=(20,10))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.margins(x=0, y=0)
plt.show()

# %% [markdown]
# Dari visualisasi diatas merupakan wordcloud kata yang paling banyak muncul pada isi ulasan yang memiliki label sentimen negatif. Kata yang paling sering muncul dan mengarah ke ulasan negatif membahas seputar : barang, harga, kotak, penyok, box, dus, tipis, putus, sobek, kualitas, karet, bolong dan sebagainya. Sehingga dari kata-kata ini bisa menjadi masukan untuk penjual dan marketplace Tokopedia untuk meningkatkan kualitas barang (produk masker kesehatan), harga, kualitas pengiriman atau pengemasan, serta kualitas produk masker Kesehatan yang paling banyak disebutkan pelanggan dalam hasil Analisa ulasan sentimen yang negatif.

# %% [markdown]
# # Ulasan Positif

# %%
train_s1 = data_label[data_label['label'] == 1]

# %%
train_s1['Ulasan_clean'] = train_s1['Ulasan_clean'].fillna('tidak ada komentar')
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_1220\1276136027.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_s1['Ulasan_clean'] = train_s1['Ulasan_clean'].fillna('tidak ada komentar')

# %%
train_s1
# Out:
#                                            Nama_Produk   Akun  \
# 1    Masker KF94 4 Ply Isi 10 Pcs Masker Medis Kese...   Yati
# 2    Masker KF94 4 Ply Isi 10 Pcs Masker Medis Kese...  Husin
# 3    Masker KF94 4 Ply Isi 10 Pcs Masker Medis Kese...  Febby
# 5    Masker KF94 4 Ply Isi 10 Pcs Masker Medis Kese...  Alden
# 6    Masker KF94 4 Ply Isi 10 Pcs Masker Medis Kese...   Heni
# ..                                                 ...    ...
# 293              Buy 1 Get 1 - Masker Primero - Sachet  M***y
# 296              Buy 1 Get 1 - Masker Primero - Sachet  Teguh
# 297              Buy 1 Get 1 - Masker Primero - Sachet  F***a
# 298              Buy 1 Get 1 - Masker Primero - Sachet  N***a
# 299              Buy 1 Get 1 - Masker Primero - Sachet  G***g
#
#                                           Ulasan_clean  label
# 1                                    bagus kirim cepat      1
# 2                                  barang sesuai pesan      1
# 3                                          panas pakai      1
# 5                                         bagus masker      1
# 6    pengirimn cepat produk bagus konsumen suka mak...      1
# ..                                                 ...    ...
# 293                                          top keren      1
# 296                   kotak penyok sana mngkn expediai      1
# 297  barang sesuai kualitas kardus penyok next time...      1
# 298                      harga promo murah kirim promo      1
# 299  proses kirim sabar ya temanteman beli paket cu...      1
#
# [270 rows x 4 columns]

# %%
all_text_s1 = ' '.join(word for word in train_s1["Ulasan_clean"])
wordcloud = WordCloud(colormap='Blues', width=1000, height=1000, mode='RGBA', background_color='white').generate(all_text_s1)
plt.figure(figsize=(20,10))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.title("Ulasan Positif")
plt.margins(x=0, y=0)
plt.show()

# %% [markdown]
# Dari visualisasi diatas merupakan wordcloud kata yang paling banyak muncul pada ulasan yang memiliki label sentimen positif. Kata yang paling sering muncul dan mengarah ke ulasan positif membahas seputar : barang, cepat, bagus, masker, aman, kualitas, sesuai, rapi, respon, aman, recommended, dan sebagainya. Sehingga dari kata-kata ini bisa menjadi masukan untuk penjual dan marketplace Tokopedia untuk menjaga kualitas atau meningkatkan kembali kualitas barang (produk masker kesehatan), kualitas yang sesuai dan aman, serta respon penjual paling banyak disebutkan pelanggan dalam hasil Analisa ulasan sentimen yang positif.

# %% [markdown]
# # Train dan Test
# Pada proses ini menggunakan library sklearn.model_selection dengan modul train_test _split untuk membagi data latih (X_train dan y_train) dan data uji (X_test dan y_test) dengan persentasi data latih 70% dan data uji 30% serta memilih label data yaitu yang merupakan variable independen dari data yaitu kolom label untuk dijadikan parameter klasifikasi prediksi.

# %%
data_label['Ulasan_clean'] = data_label['Ulasan_clean'].fillna("tidak ada komentar")
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_1220\2139537248.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_label['Ulasan_clean'] = data_label['Ulasan_clean'].fillna("tidak ada komentar")

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(data_label['Ulasan_clean'], data_label['label'], 
                                                    test_size=0.1, stratify=data_label['label'], random_state=30)

# %% [markdown]
# # TF_IDF
# Pada proses ini menggunakan pembobotan TF-IDF(term frequency–inverse document) untuk menghitung manual dengan menggunakan python pembobotan kata dalam dokumen data ulasan.

# %%
import numpy as np

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
vectorizer = TfidfVectorizer(decode_error='replace', encoding='utf-8')

# %%
X_train = vectorizer.fit_transform(X_train)
X_test = vectorizer.transform(X_test)

print(X_train.shape)
print(X_test.shape)
# Out:
# (270, 428)
# (30, 428)

# %%
X_train = X_train.toarray()
X_test = X_test.toarray()

# %% [markdown]
# # Machine Learning

# %%
from sklearn.naive_bayes import GaussianNB

# %%
nb = GaussianNB()

# %%
from sklearn.model_selection import RepeatedStratifiedKFold
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import StratifiedKFold

#deklarasi metode cross validation
cv_method = RepeatedStratifiedKFold(n_splits=5,  n_repeats=3, random_state=999)
#tuning hyperparameter menggunakan gridsearch

params_NB = {'var_smoothing': np.logspace(0,-9, num=100)}
gscv_nb = GridSearchCV(estimator=nb, 
                 param_grid=params_NB, 
                 cv=cv_method,   # use any cross validation technique 
                 verbose=1, 
                 scoring='accuracy') 

#Fitting ke Model
gscv_nb.fit(X_train,y_train)
#mendapatkan hyperparameters terbaik
gscv_nb.best_params_
# Out:
# Fitting 15 folds for each of 100 candidates, totalling 1500 fits
# {'var_smoothing': 1.0}

# %%
nb = GaussianNB(var_smoothing=1.0)

# %%
nb.fit(X_train, y_train)
# Out:
# GaussianNB(var_smoothing=1.0)

# %%
y_pred_nb = nb.predict(X_test)

# %%
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report

# %%
print('--------------------- confusion matrix  ----------------------------')
print(confusion_matrix(y_test, y_pred_nb))
print('--------------------- classification report  ----------------------------')
print(classification_report(y_test, y_pred_nb))
# Out:
# --------------------- confusion matrix  ----------------------------
# [[ 0  3]
#  [ 1 26]]
# --------------------- classification report  ----------------------------
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         3
#            1       0.90      0.96      0.93        27
#
#     accuracy                           0.87        30
#    macro avg       0.45      0.48      0.46        30
# weighted avg       0.81      0.87      0.84        30

# %% [markdown]
# Setelah dilakukan pembagian data latih dan data uji serta pembobotan tf-idf selanjutnya dapat dilakukan proses klasifikasi prediksi menggunakan model algoritma Naïve Bayes seperti proses yang ditunjukkan pada gambar 4. Didapatkan model algoritma Naïve Bayes dapat memberikan akurasi yang cukup baik sampai 88%.

# %% [markdown]
# Dari hasil penelitian menggunakan Metode Algoritma Naïve Bayes untuk mengetahui sentimen ulasan pengguna dengan klasifikasi 2 kelas positif dan negative dengan pendekatan NLP menghasilkan nilai akurasi sebesar 88%. Selain itu, didapatkan bahwa Analisa Sentimen pada ulasan marketplace Tokopedia pada produk masker kesehatan menunjukan lebih banyak pada ulasan yang positif. Ini berarti pelayanan dan produk masker Kesehatan yang disediakan di marketplace Tokopedia sudah cukup baik.

# %% [markdown]
# Dari hasil Analisis diatas dapat disimpulkan dari produk pencarian masker kesehatan pada Tokopedia menampilkan data yang menunjukan ulasan positif lebih dominan daripada hasil ulasan negatif dan untuk ulasan negatif kata yang paling sering muncul adalah seputar kualitas produk yang tipis,mudah putus, sobek atau bolong, kualitas karetnya dan pada pengemasan yaitu kotak/dus penyok dan untuk analisa positif kata yang paling sering muncul adalah seputar kualitas produk yang sesuai dan rapi, pengiriman yang aman dan cepat dan respon penjual.
